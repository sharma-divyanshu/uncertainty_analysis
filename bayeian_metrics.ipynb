# %%
from bayesian_model import GPSparseBayesModel
from data_loader import data_loader
from utils import ause, return_replicates
from utils import permutation_test_ause, expected_calibration_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import itertools
import numpy as np
import pandas as pd

# %%
datasets = data_loader()

def split(X, y):
    X, y = np.array(X), np.array(y).ravel()
    return train_test_split(X, y, test_size=0.2, stratify=y, random_state=7200)

# %% [markdown]
# Diabetes

# %%
kernel = 'rbf'
loss = 'trace_meanfield_elbo'
induced_points_method = 'random'

X, y = datasets['diabetes']
X_train, X_test, y_train, y_test = split(X, y)

model = GPSparseBayesModel(**{"random_seed": 7200, 
                              "num_induced_samples": 'sqrt', 
                              "kernel": kernel,
                              "loss": loss,
                              "induced_points_method": induced_points_method
                            })
model.after_setup()
model.train(X_train, y_train)
pred_probs, pred_vars, pred_labels = model.test(X_test, None)
print("Accuracy:", accuracy_score(y_test, pred_labels), "F1 Score:", f1_score(y_test, pred_labels))
permutation_test_ause(pred_probs, pred_vars, y_test)
# Out:
# Accuracy: 0.7922077922077922 F1 Score: 0.6666666666666666

# %% [markdown]
# Ionosphere

# %%
kernel = 'rbf'
loss = 'trace_elbo'
induced_points_method = 'kmeans'

X, y = datasets['ionosphere']
X_train, X_test, y_train, y_test = split(X, y)

model = GPSparseBayesModel(**{"random_seed": 7200, 
                              "num_induced_samples": 'sqrt', 
                              "kernel": kernel,
                              "loss": loss,
                              "induced_points_method": induced_points_method
                            })
model.after_setup()
model.train(X_train, y_train)
pred_probs, pred_vars, pred_labels = model.test(X_test, None)
print("Accuracy:", accuracy_score(y_test, pred_labels), "F1 Score:", f1_score(y_test, pred_labels))
permutation_test_ause(pred_probs, pred_vars, y_test)
# Out:
# Accuracy: 0.9014084507042254 F1 Score: 0.9278350515463919

# %% [markdown]
# Red wine

# %%
kernel = 'rbf'
loss = 'trace_elbo'
induced_points_method = 'kmeans'

X, y = datasets['red-wine']
X_train, X_test, y_train, y_test = split(X, y)

model = GPSparseBayesModel(**{"random_seed": 7200, 
                              "num_induced_samples": 'sqrt', 
                              "kernel": kernel,
                              "loss": loss,
                              "induced_points_method": induced_points_method
                            })
model.after_setup()
model.train(X_train, y_train)
pred_probs, pred_vars, pred_labels = model.test(X_test, None)
print("Accuracy:", accuracy_score(y_test, pred_labels), "F1 Score:", f1_score(y_test, pred_labels))
permutation_test_ause(pred_probs, pred_vars, y_test)
# Out:
# Accuracy: 0.6875 F1 Score: 0.7023809523809523

# %%
kernel = 'poly'
loss = 'trace_meanfield_elbo'
induced_points_method = 'random'

X, y = datasets['red-wine']
X_train, X_test, y_train, y_test = split(X, y)

model = GPSparseBayesModel(**{"random_seed": 7200, 
                              "num_induced_samples": 100, 
                              "kernel": kernel,
                              "loss": loss,
                              "induced_points_method": induced_points_method
                            })
model.after_setup()
model.train(X_train, y_train)
pred_probs, pred_vars, pred_labels = model.test(X_test, None)
print("Accuracy:", accuracy_score(y_test, pred_labels), "F1 Score:", f1_score(y_test, pred_labels))
permutation_test_ause(pred_probs, pred_vars, y_test)
# Out:
# Accuracy: 0.690625 F1 Score: 0.679611650485437

# %% [markdown]
# White wine

# %%
kernel = 'rbf'
loss = 'trace_elbo'
induced_points_method = 'kmeans'

X, y = datasets['white-wine']
X_train, X_test, y_train, y_test = split(X, y)

model = GPSparseBayesModel(**{"random_seed": 7200, 
                              "num_induced_samples": 'sqrt', 
                              "kernel": kernel,
                              "loss": loss,
                              "induced_points_method": induced_points_method
                            })
model.after_setup()
model.train(X_train, y_train)
pred_probs, pred_vars, pred_labels = model.test(X_test, None)
print("Accuracy:", accuracy_score(y_test, pred_labels), "F1 Score:", f1_score(y_test, pred_labels))
permutation_test_ause(pred_probs, pred_vars, y_test)
# Out:
# Accuracy: 0.8020408163265306 F1 Score: 0.35333333333333333

# %%
kernel = 'linear'
loss = 'trace_meanfield_elbo'
induced_points_method = 'random'

X, y = datasets['white-wine']
X_train, X_test, y_train, y_test = split(X, y)

model = GPSparseBayesModel(**{"random_seed": 7200, 
                              "num_induced_samples": 'sqrt', 
                              "kernel": kernel,
                              "loss": loss,
                              "induced_points_method": induced_points_method
                            })
model.after_setup()
model.train(X_train, y_train)
pred_probs, pred_vars, pred_labels = model.test(X_test, None)
print("Accuracy:", accuracy_score(y_test, pred_labels), "F1 Score:", f1_score(y_test, pred_labels))
permutation_test_ause(pred_probs, pred_vars, y_test)
# Out:
# Accuracy: 0.7816326530612245 F1 Score: 0.01834862385321101
